# %% [markdown]
# # Работа в терминале
#
#
# ![image.png](attachment:44fc2ceb-cee4-4078-9506-89f3f4b09578.png)

# %% [markdown]
# ## Задание 1:
# Запустите терминал Simba
#
# ![image.png](attachment:3742debb-b6c9-4181-9d96-e8f5d4708d49.png)

# %% [markdown]
# ## Задание 2:
# Выведите текущую рабочую директорию, в которой вы находитесь. Если это не директория /home/jovyan, то перейдите в нее.

# %% [markdown]
# ## Задание 3:
# Удалите папки и файлы, созданные ранее (Task 1).
# В вашей папке должны остаться следующие папки и файлы:
# __DATA
#
# __MANUAL
#
# __SHARED
#
# derby.log
#
# lost+found

# %% [markdown]
# ## Задание 4:
#
# Создайте папку с названием Task2 и перейдите в нее.

# %% [markdown]
# ## Задание 5:
# Выполните с помощью команды git clone клонирование репозитория:
#
# https://github.com/monitor81/big_data_course
